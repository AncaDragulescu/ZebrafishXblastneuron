# %%
import navis
import matplotlib.pyplot as plt
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#example plotting 
nl = navis.example_neurons()
fig, ax = navis.plot2d(nl, method='2d') 
plt.show()

# %%
#custom plotting
neur1 = navis.TreeNeuron('/Users/anca/Desktop/all_database_compare/inverse_T_190909_7_4.swc')
neur2 = navis.TreeNeuron('/Users/anca/Desktop/sorted_neurons/T_190531_12_1.swc')
align = navis.TreeNeuron('/Users/anca/Desktop/all_database_compare/align_T_190909_7_4.swc')

nl = navis.NeuronList([neur1, neur2, align])

# %%
fig = nl.plot3d()
# Out:
# <div>                            <div id="12a1dd51-9904-4a6f-8480-647a1d6b0e3f" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12a1dd51-9904-4a6f-8480-647a1d6b0e3f")) {                    Plotly.newPlot(                        "12a1dd51-9904-4a6f-8480-647a1d6b0e3f",                        [{"hoverinfo": "none", "legendgroup": "29b3f5ba-4088-43d3-b2c2-2d66d6c6202e", "line": {"color": "rgb(219,94,86)", "width": 2}, "mode": "lines", "name": "inverse_T_190909_7_4", "showlegend": true, "type": "scatter3d", "x": [-217.17300415039062, -215.84800720214844, -214.50900268554688, -213.09500122070312, -211.67999267578125, -210.27099609375, -208.8679962158203, -207.4669952392578, -206.04200744628906, -204.6300048828125, -203.23399353027344, -201.8200073242187
# ...

# %%
#showing progression 
orig = navis.TreeNeuron('/Users/anca/Desktop/sorted_neurons/T_150518_13_1_full_tracing.swc')
downloaded = navis.TreeNeuron('/Users/anca/Downloads/baier/CNG_version/150518_13_1_full_tracing.CNG.swc')
prepr = navis.TreeNeuron('/Users/anca/Downloads/baier/CNG_version/150518_13_1_full_tracing_preprocessed.CNG.swc')
sort = navis.TreeNeuron('/Users/anca/Downloads/baier/CNG_version/150518_13_1_full_tracing_preprocessed_sorted.CNG.swc')
invp = navis.TreeNeuron('/Users/anca/Downloads/baier/CNG_version/150518_13_1_full_tracing_preprocessed_sorted_invp.CNG.swc')
align = navis.TreeNeuron('/Users/anca/Downloads/baier/CNG_version/150518_13_1_full_tracing_aligned.CNG.swc')

# orig.plot3d()
# sort.plot3d()
# invp.plot3d()


new_nl = navis.NeuronList([orig, downloaded, align])

new_nl.plot3d()
# Out:
# <div>                            <div id="084621ef-0bdd-4a0f-8308-142967be5b16" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("084621ef-0bdd-4a0f-8308-142967be5b16")) {                    Plotly.newPlot(                        "084621ef-0bdd-4a0f-8308-142967be5b16",                        [{"hoverinfo": "none", "legendgroup": "8bdc343d-c8b3-4277-a09e-cfd4570059cf", "line": {"color": "rgb(219,94,86)", "width": 2}, "mode": "lines", "name": "T_150518_13_1_full_tracing", "showlegend": true, "type": "scatter3d", "x": [-145.8000030517578, -144.07000732421875, -142.44000244140625, -140.6999969482422, -138.91000366210938, -136.97999572753906, -135.05999755859375, -133.1199951171875, -131.13999938964844, -132.05999755859375, -130.08999633789062, -128.1300
# ...

# %%
#quick neuron compare

n1 = navis.TreeNeuron('/Users/anca/Desktop/Zbrain_neurons_flipped_right/T_190531_12_1.swc')
n2 = navis.TreeNeuron('/Users/anca/Desktop/sorted_neurons/align_T_190909_7_4.swc')

n1.plot3d()
n2.plot3d()
# Out:
# <div>                            <div id="bd9a8472-7c3e-4807-a26c-a46e0b9b0062" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd9a8472-7c3e-4807-a26c-a46e0b9b0062")) {                    Plotly.newPlot(                        "bd9a8472-7c3e-4807-a26c-a46e0b9b0062",                        [{"hoverinfo": "none", "legendgroup": "5c830297-b2cb-4cb9-8654-29757b70a6e9", "line": {"color": "rgb(242,165,10)", "width": 2}, "mode": "lines", "name": "T_190531_3_4", "showlegend": true, "type": "scatter3d", "x": [113.14910125732422, 116.54759979248047, 118.59649658203125, 121.41230010986328, 119.8583984375, 122.01754760742188, 124.26566314697266, 126.6177978515625, 129.33084106445312, 132.61904907226562, 136.21554565429688, 139.60899353027344, 142.98745727539
# ...

# %%
n1 = navis.TreeNeuron('/Users/anca/Desktop/Zbrain_neurons_flipped_right/T_190527_1181xBG_7_1.swc')
n2 = navis.TreeNeuron('/Users/anca/Desktop/sorted_neurons/T_190527_1181xBG_7_1.swc')

aux_nl = navis.NeuronList([n1,n2])

n1.plot3d()
n2.plot3d()
# Out:
# <div>                            <div id="c3c98ada-abea-4597-b6a1-48ee2a4bf4a0" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c3c98ada-abea-4597-b6a1-48ee2a4bf4a0")) {                    Plotly.newPlot(                        "c3c98ada-abea-4597-b6a1-48ee2a4bf4a0",                        [{"hoverinfo": "none", "legendgroup": "a0fc2e8f-fe78-442f-b2e5-b64472d8cbca", "line": {"color": "rgb(242,165,10)", "width": 2}, "mode": "lines", "name": "T_190527_1181xBG_7_1", "showlegend": true, "type": "scatter3d", "x": [147.0137939453125, 144.9949951171875, 140.83584594726562, 145.64535522460938, 153.1416015625, 160.06265258789062, 165.943603515625, 171.47744750976562, 172.68919372558594, 174.88595581054688, 177.71180725097656, 181.00875854492188, 185.804504
# ...

# %%
#list compare
