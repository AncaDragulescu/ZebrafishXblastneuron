# %%
import pandas as pd

# %%
#read in batch computed data
data = pd.read_csv('/Users/anca/Desktop/sorted_neurons/neuron_db.csv')
data
# Out:
#                                                swc_file  num_nodes  \
# 0     /Users/anca/Desktop/sorted_neurons/20150327_10...      231.0
# 1     /Users/anca/Desktop/sorted_neurons/20150402_10...      409.0
# 2     /Users/anca/Desktop/sorted_neurons/20160512_10...      347.0
# 3     /Users/anca/Desktop/sorted_neurons/20160519_10...      610.0
# 4     /Users/anca/Desktop/sorted_neurons/20160519_10...      540.0
# ...                                                 ...        ...
# 3113  /Users/anca/Desktop/sorted_neurons/T_200107_6_...      103.0
# 3114  /Users/anca/Desktop/sorted_neurons/T_200107_7_...      289.0
# 3115  /Users/anca/Desktop/sorted_neurons/T_200107_7_...      403.0
# 3116  /Users/anca/Desktop/sorted_neurons/T_200107_8_...      302.0
# 3117  /Users/anca/Desktop/sorted_neurons/T_200107_8_...      344.0
#
#       soma_surface  num_stems  num_bifurcations  num_branches  num_of_tips  \
# 0        51.275818        2.0               9.0          18.0         10.0
# ...

# %%
print (data.columns)
# Out:
# Index(['swc_file', 'num_nodes', 'soma_surface', 'num_stems',
#        'num_bifurcations', 'num_branches', 'num_of_tips', 'overall_x_span',
#        'overall_y_span', 'overall_z_span', 'average_diameter', 'total_length',
#        'total_surface', 'total_volume', 'max_euclidean_distance',
#        'max_path_distance', 'max_branch_order', 'average_contraction',
#        'average_fragmentation', 'parent_daughter_ratio',
#        'bifurcation_angle_local', 'bifurcation_angle_remote', 'moment1',
#        'moment2', 'moment3', 'moment4', 'moment5', 'moment6', 'moment7',
#        'moment8', 'moment9', 'moment10', 'moment11', 'moment12', 'moment13',
#        'ave_R'],
#       dtype='object')

# %%
print(data['total_length'][])

# %%
print(data.hist(column = 'num_nodes', bins = 20))
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x117f5d630>]]

# %%
print(data.hist(column = 'moment1', bins = 20))
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x118e88208>]]

# %%
print(data.hist(column = 'moment13', bins = 20))
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x118e08080>]]

# %%
print(data.hist(column = 'total_volume', bins = 20))
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x118f5c3c8>]]

# %%
print(data.hist(column = 'num_branches', bins = 20))
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x118e229e8>]]

# %%
print(data.hist(column = 'average_fragmentation', bins = 20))
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x118ceb198>]]

# %%
print(data.plot.scatter('total_volume','total_surface'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data_norm = data.copy()
data_norm.iloc[:,1:-1] = scaler.fit_transform(data.iloc[:,1:-1].to_numpy())
data_norm.head()
# Out:
#                                             swc_file  num_nodes  soma_surface  \
# 0  /Users/anca/Desktop/sorted_neurons/20150327_10...  -0.536948     -0.740075
# 1  /Users/anca/Desktop/sorted_neurons/20150402_10...   0.303419     -1.125817
# 2  /Users/anca/Desktop/sorted_neurons/20160512_10...   0.010707     -0.747406
# 3  /Users/anca/Desktop/sorted_neurons/20160519_10...   1.252373     -0.617825
# 4  /Users/anca/Desktop/sorted_neurons/20160519_10...   0.921892     -0.825650
#
#    num_stems  num_bifurcations  num_branches  num_of_tips  overall_x_span  \
# 0   0.436206          0.198991      0.135822     0.168371       -0.375027
# 1  -0.633889          1.170474      1.184471     1.135187        0.977043
# 2  -0.633889          1.332388      1.345802     1.296323       -0.193661
# 3  -0.633889          1.656216      1.668463     1.618594        0.435108
# 4  -0.633889          0.198991      0.216487     0.168371        0.388855
#
# ...

# %%
data_norm['swc_file'] = data_norm['swc_file'].str.split(r'/').str.get(5)
data_norm.head()
# Out:
#                                          swc_file  num_nodes  soma_surface  \
# 0          20150327_1013_BGUG_HuC_ltRFP_d5_F2.swc  -0.536948     -0.740075
# 1          20150402_1013_BGUG_HuC_ltRFP_d5_F3.swc   0.303419     -1.125817
# 2  20160512_1013_BGUG_HuC_ltRFP_d6_F6_Neuron2.swc   0.010707     -0.747406
# 3          20160519_1013_BGUG_HuC_ltRFP_d6_F1.swc   1.252373     -0.617825
# 4          20160519_1013_BGUG_HuC_ltRFP_d6_F6.swc   0.921892     -0.825650
#
#    num_stems  num_bifurcations  num_branches  num_of_tips  overall_x_span  \
# 0   0.436206          0.198991      0.135822     0.168371       -0.375027
# 1  -0.633889          1.170474      1.184471     1.135187        0.977043
# 2  -0.633889          1.332388      1.345802     1.296323       -0.193661
# 3  -0.633889          1.656216      1.668463     1.618594        0.435108
# 4  -0.633889          0.198991      0.216487     0.168371        0.388855
#
# ...

# %%
#getting distance matrix
import numpy as np
from sklearn.metrics import pairwise_distances
from scipy.spatial.distance import cosine

features = data_norm.iloc[:,1:-1].to_numpy(na_value = 0)

# %%
print(features)
# Out:
# [[-0.53694849 -0.7400751   0.43620615 ...  2.15760732 -2.50400196
#    2.63523122]
#  [ 0.30341889 -1.12581708 -0.63388887 ...  1.69379756 -2.04469753
#    2.19609184]
#  [ 0.01070666 -0.74740645 -0.63388887 ...  1.8544028  -2.30844113
#    2.55348626]
#  ...
#  [ 0.2750919   0.62060968  0.43620615 ...  0.6334399  -0.69335936
#    0.62902116]
#  [-0.20174577 -0.98710351 -0.63388887 ... -0.63650298  0.6146682
#   -0.62767446]
#  [-0.00345684  0.0370303   0.43620615 ... -0.92858895  0.73084157
#   -0.60071713]]

# %%
similarity_matrix = 1-pairwise_distances(features, metric="cosine")

# %%
print(similarity_matrix)
# Out:
# [[ 1.          0.76924212  0.90978032 ...  0.41197433 -0.404908
#   -0.13248966]
#  [ 0.76924212  1.          0.88934277 ...  0.40951314 -0.35761468
#   -0.05827237]
#  [ 0.90978032  0.88934277  1.         ...  0.3514904  -0.46892572
#    0.03820843]
#  ...
#  [ 0.41197433  0.40951314  0.3514904  ...  1.         -0.23210899
#   -0.48216867]
#  [-0.404908   -0.35761468 -0.46892572 ... -0.23210899  1.
#   -0.05830167]
#  [-0.13248966 -0.05827237  0.03820843 ... -0.48216867 -0.05830167
#    1.        ]]

# %%
new_cols = data_norm['swc_file'].to_list()
df_sim_matrix = pd.DataFrame(similarity_matrix,index=new_cols,columns=new_cols)

# %%
df_sim_matrix.head()
# Out:
#                                                 20150327_1013_BGUG_HuC_ltRFP_d5_F2.swc  \
# 20150327_1013_BGUG_HuC_ltRFP_d5_F2.swc                                        1.000000
# 20150402_1013_BGUG_HuC_ltRFP_d5_F3.swc                                        0.769242
# 20160512_1013_BGUG_HuC_ltRFP_d6_F6_Neuron2.swc                                0.909780
# 20160519_1013_BGUG_HuC_ltRFP_d6_F1.swc                                       -0.034908
# 20160519_1013_BGUG_HuC_ltRFP_d6_F6.swc                                        0.320275
#
#                                                 20150402_1013_BGUG_HuC_ltRFP_d5_F3.swc  \
# 20150327_1013_BGUG_HuC_ltRFP_d5_F2.swc                                        0.769242
# 20150402_1013_BGUG_HuC_ltRFP_d5_F3.swc                                        1.000000
# 20160512_1013_BGUG_HuC_ltRFP_d6_F6_Neuron2.swc                                0.889343
# 20160519_1013_BGUG_HuC_ltRFP_d6_F1.swc                                        0.514426
# ...

# %%
df_sim_matrix.nlargest(20, ['T_190531_3_4.swc'])['T_190531_3_4.swc']
# Out:
# T_190531_3_4.swc                                  1.000000
# T_160927_26_1.swc                                 0.930308
# T_170627_13_5.swc                                 0.929811
# 20160922_1013_BGUG_HuC_ltRFP_d6_F3.swc            0.928747
# T_190221_17_1.swc                                 0.928734
# 20161004_1013_BGUG_HuC_ltRFP_d5_F1_Neuron2.swc    0.928635
# T_190221_10_1.swc                                 0.928378
# T_190131_10_1.swc                                 0.928023
# T_190221_3_2.swc                                  0.927119
# 20170819_1013_BGUG_HuC_ltRFP_d7_F6.swc            0.926192
# T_160524_8_1.swc                                  0.925981
# T_161116_18_2.swc                                 0.925729
# T_161026_HuCxBG_erksyp_2_5.swc                    0.924278
# T_190125_9_3.swc                                  0.922946
# T_190909_5_1.swc                                  0.922216
# T_190121_9_4.swc                                  0.921950
# ...

# %%
print(df_sim_matrix.hist(column = 'T_190531_3_4.swc', bins = 20))
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x12205f3c8>]]

# %%
df_sim_matrix['T_190531_3_5.swc']['T_190426_1181xBG_7_2.swc']
# Out:
# 0.12969026686117413

# %% [markdown]
# <h> HERE <h>

# %%
#analizing data from 3000 comparisons
features = pd.read_csv('/Users/anca/Desktop/all_database_compare/features.csv')
features
# Out:
#                                                swc_file  num_nodes  \
# 0     /Users/anca/Desktop/all_database_compare/align...      272.0
# 1     /Users/anca/Desktop/all_database_compare/align...      484.0
# 2     /Users/anca/Desktop/all_database_compare/align...      272.0
# 3     /Users/anca/Desktop/all_database_compare/align...      388.0
# 4     /Users/anca/Desktop/all_database_compare/align...      272.0
# ...                                                 ...        ...
# 5965  /Users/anca/Desktop/all_database_compare/inver...      353.0
# 5966  /Users/anca/Desktop/all_database_compare/inver...      103.0
# 5967  /Users/anca/Desktop/all_database_compare/inver...      289.0
# 5968  /Users/anca/Desktop/all_database_compare/inver...      403.0
# 5969  /Users/anca/Desktop/all_database_compare/inver...      344.0
#
#       soma_surface  num_stems  num_bifurcations  num_branches  num_of_tips  \
# 0        12.566371        1.0               0.0           1.0        136.0
# ...

# %%
print(features.columns)
# Out:
# Index(['swc_file', 'num_nodes', 'soma_surface', 'num_stems',
#        'num_bifurcations', 'num_branches', 'num_of_tips', 'overall_x_span',
#        'overall_y_span', 'overall_z_span', 'average_diameter', 'total_length',
#        'total_surface', 'total_volume', 'max_euclidean_distance',
#        'max_path_distance', 'max_branch_order', 'average_contraction',
#        'average_fragmentation', 'parent_daughter_ratio',
#        'bifurcation_angle_local', 'bifurcation_angle_remote', 'moment1',
#        'moment2', 'moment3', 'moment4', 'moment5', 'moment6', 'moment7',
#        'moment8', 'moment9', 'moment10', 'moment11', 'moment12', 'moment13',
#        'ave_R'],
#       dtype='object')

# %%
features['swc_file'] = features['swc_file'].str.split(r'/').str.get(5)
features.head()
# Out:
#                                             swc_file  num_nodes  soma_surface  \
# 0       align_20150327_1013_BGUG_HuC_ltRFP_d5_F2.swc      272.0     12.566371
# 1       align_20150402_1013_BGUG_HuC_ltRFP_d5_F3.swc      484.0     12.566371
# 2  align_20160512_1013_BGUG_HuC_ltRFP_d6_F6_Neuro...      272.0     12.566371
# 3       align_20160519_1013_BGUG_HuC_ltRFP_d6_F1.swc      388.0     12.566371
# 4  align_20160526_1013_BGUG_HuC_ltRFP_d6_F2_Neuro...      272.0     12.566371
#
#    num_stems  num_bifurcations  num_branches  num_of_tips  overall_x_span  \
# 0        1.0               0.0           1.0        136.0      172.949999
# 1        1.0               0.0           1.0        242.0      685.420990
# 2        1.0               0.0           1.0        136.0      232.027000
# 3        1.0               0.0           1.0        194.0      376.069992
# 4        1.0               0.0           1.0        136.0      384.079989
#
# ...

# %%
print(features.iloc[2975:3025,:])
# Out:
#                                                swc_file  num_nodes  \
# 2975                             align_T_191220_3_1.swc      272.0
# 2976                             align_T_191220_4_1.swc      316.0
# 2977                             align_T_191220_5_1.swc      366.0
# 2978                             align_T_200107_0_1.swc      488.0
# 2979                             align_T_200107_0_2.swc      154.0
# 2980                             align_T_200107_3_1.swc      368.0
# 2981                             align_T_200107_6_1.swc      364.0
# 2982                             align_T_200107_7_1.swc      438.0
# 2983                             align_T_200107_7_2.swc      366.0
# 2984                             align_T_200107_8_2.swc      482.0
# 2985     inverse_20150327_1013_BGUG_HuC_ltRFP_d5_F2.swc      231.0
# 2986     inverse_20150402_1013_BGUG_HuC_ltRFP_d5_F3.swc      409.0
# 2987  inverse_20160512_1013_BGUG_HuC_ltRFP_d6_F6_Neu...      347.0
# ...

# %%
features = features.iloc[:2985,:]

# %%
align_features = features.iloc[:2985,:]

# %%
align_features['distance'] = align_features['total_length']/align_features['num_nodes']

# %%
align_features
# Out:
#                                                swc_file  num_nodes  \
# 0          align_20150327_1013_BGUG_HuC_ltRFP_d5_F2.swc      272.0
# 1          align_20150402_1013_BGUG_HuC_ltRFP_d5_F3.swc      484.0
# 2     align_20160512_1013_BGUG_HuC_ltRFP_d6_F6_Neuro...      272.0
# 3          align_20160519_1013_BGUG_HuC_ltRFP_d6_F1.swc      388.0
# 4     align_20160526_1013_BGUG_HuC_ltRFP_d6_F2_Neuro...      272.0
# ...                                                 ...        ...
# 2980                             align_T_200107_3_1.swc      368.0
# 2981                             align_T_200107_6_1.swc      364.0
# 2982                             align_T_200107_7_1.swc      438.0
# 2983                             align_T_200107_7_2.swc      366.0
# 2984                             align_T_200107_8_2.swc      482.0
#
#       soma_surface  num_stems  num_bifurcations  num_branches  num_of_tips  \
# 0        12.566371        1.0               0.0           1.0        136.0
# ...

# %%
align_features.hist(column = 'distance', bins = 20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11dc71eb8>]],
#       dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(align_features['distance'], bins = 50, range = [0,100])
plt.xlabel('NDS')
plt.ylabel('number of neurons')
plt.title('Distribution of NDS with respect to T_190531_12_1')
# Out:
# Text(0.5, 1.0, 'Distribution of NDS with respect to T_190531_12_1')

# %%
plt.scatter(align_features['distance'],align_features['total_length'])

# %%
align_features.nsmallest(30, ['distance'])[['swc_file','distance']]
# Out:
#                              swc_file  distance
# 2531          align_T_190531_12_1.swc  0.000000
# 2546           align_T_190531_3_4.swc  2.894854
# 2782           align_T_190918_8_1.swc  2.924631
# 2756           align_T_190909_7_4.swc  3.297211
# 1867          align_T_170714_11_3.swc  3.302963
# 2732           align_T_190812_8_3.swc  4.082337
# 2264           align_T_190131_9_2.swc  4.291658
# 2460  align_T_190426_1181xBG_13_2.swc  4.857652
# 2932          align_T_191128_18_3.swc  5.137516
# 2536          align_T_190531_12_6.swc  5.184778
# 2759           align_T_190909_9_2.swc  5.243909
# 2547           align_T_190531_3_5.swc  5.274572
# 2178          align_T_190125_13_4.swc  5.377377
# 1266           align_T_161031_0_3.swc  5.492033
# 1586            align_T_16119_5_3.swc  5.668176
# 514            align_T_160518_2_2.swc  5.772836
# 573            align_T_160524_5_5.swc  5.853051
# 2575           align_T_190624_4_1.swc  5.879203
# 1968           align_T_180112_7_1.swc  5.889627
# ...

# %%
new neurons to try: query = T_190531_12_1.swc 
    same other = T_170714_11_3.swc -mirror image 
    T_190426_1181xBG_7_2.swc same
    T_190531_11_1.swc same    

        **T_190531_3_4.swc very complex and mirrored
        T_190531_3_5.swc  same  ok
        T_190909_9_2.swc same    ok
        T_190812_8_3.swc  s    ok
        T_190624_4_1.swc  s   ok
        T_150304_2_4.swc  diff
        T_190527_1181xBG_7_1.swc intermediate

        T_160610_HuCxBG_19_1.swc very diff
        T_160426_5_1.swc very very diff
        T_170627_10_3.swc v diff

        FT_T_lG_6.swc olfactory bulb very diff
        
        
        PLLG:
 	T_170714_11_3.swc   ok
	T_190426_1181xBG_7_2.swc   #not in the database, i.e. the projection step failed ---try projection again . I did and it went through, alignment is weird again
	T_190527_1181xBG_7_1.swc  #not that similar anyway
	T_190531_11_1.swc   #exists in dataset, the projection seems fine, the alignment seems off
	T_190531_12_1.swc   same
	T_190531_3_4.swc    ok
	T_190531_3_5.swc    ok
	T_190624_4_1.swc    ok
	T_190812_8_3.swc    ok
	T_190909_9_2.swc    ok
	T_190918_8_1.swc    ok  
        

	T_190812_1_1.swc (terminations in PLLG)

    
align_T_190531_12_1.swc	0.000000
2546	align_T_190531_3_4.swc	2.894854  ok
2782	align_T_190918_8_1.swc	2.924631  ok
2756	align_T_190909_7_4.swc	3.297211
1867	align_T_170714_11_3.swc	3.302963   ok
2732	align_T_190812_8_3.swc	4.082337   ok
2264	align_T_190131_9_2.swc	4.291658
2460	align_T_190426_1181xBG_13_2.swc	4.857652   hmm
2932	align_T_191128_18_3.swc	5.137516
2536	align_T_190531_12_6.swc	5.184778
2759	align_T_190909_9_2.swc	5.243909    ok
2547	align_T_190531_3_5.swc	5.274572    ok
2178	align_T_190125_13_4.swc	5.377377
1266	align_T_161031_0_3.swc	5.492033
1586	align_T_16119_5_3.swc	5.668176
514	align_T_160518_2_2.swc	5.772836
573	align_T_160524_5_5.swc	5.853051
2575	align_T_190624_4_1.swc	5.879203    ok
1968	align_T_180112_7_1.swc	5.889627
766	align_T_160705_6_2.swc	5.898277
2484	align_T_190523_4_2_M.swc	6.004233
814	align_T_160708_HuCxBG_5_1.swc	6.016646
1807	align_T_170627_15_2.swc	6.063021
1891	align_T_170821_10_4.swc	6.173206
320	align_T_150707_8_3_full.swc	6.321383
194	align_T_150304_2_3_d.swc	6.365434     hmm
2283	align_T_190206_25_1.swc	6.374549
185	align_inverse_projection.swc	6.387806
765	align_T_160705_6_1.swc	6.504885
2119	align_T_190121_14_1.swc	6.635162
